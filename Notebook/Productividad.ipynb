# %% [markdown]
# # Calculo de Productividad

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
dict_gral = pd.read_excel('../Data/horarios MADRE.xls', sheet_name=None)

# %%
for nombre_hoja, dataframe_hoja in dict_gral.items():
    print(f"\nProcesando la hoja: '{nombre_hoja}'")
    print(f"Tipo de objeto: {type(dataframe_hoja)}")
    print("Primeras 5 filas:")
    print(dataframe_hoja.head())
    print(f"Dimensiones (filas, columnas): {dataframe_hoja.shape}")
    print("-" * 50)
# Out:
# Procesando la hoja: 'BERNALD Alberto'
# Tipo de objeto: <class 'pandas.core.frame.DataFrame'>
# Primeras 5 filas:
#    QUINCENA       Unnamed: 1           Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0       2.0  Bernald Alberto  2023-07-01 07:49:21         0.0    ENTRADA
# 1       2.0  Bernald Alberto  2023-07-01 12:03:48         1.0     SALIDA
# 2       2.0  Bernald Alberto  2023-07-04 07:22:50         0.0    ENTRADA
# 3       2.0  Bernald Alberto  2023-07-04 12:01:06         1.0     SALIDA
# 4       2.0  Bernald Alberto  2023-07-04 15:12:28         0.0    ENTRADA
#
#   HS NORMALES HS NOCTURNAS  EXTRAS  TOTAL EX
# 0         NaN          NaN     NaN       NaN
# 1         NaN          NaN     NaN       4.0
# 2         NaN          NaN     NaN       NaN
# 3         4.5          NaN     NaN       NaN
# 4         NaN          NaN     NaN       NaN
# Dimensiones (filas, columnas): (1254, 9)
# --------------------------------------------------
#
# Procesando la hoja: 'ARANDA Marcelo'
# ...
